# %%
from date_transform import DateTransform
import pandas as pd

# %%
data_finance=pd.read_csv('loan_payments_data.csv')
data_finance.head()
# Out:
#          id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0  38676116   41461848         8000         8000.0             8000.0
# 1  38656203   41440010        13200        13200.0            13200.0
# 2  38656154   41439961        16000        16000.0            16000.0
# 3  38656128   41439934        15000        15000.0            15000.0
# 4  38656121   41439927        15000        15000.0            15000.0
#
#         term  int_rate  instalment grade sub_grade  ... recoveries  \
# 0  36 months      7.49      248.82     A        A4  ...        0.0
# 1  36 months      6.99      407.52     A        A3  ...        0.0
# 2  36 months      7.49      497.63     A        A4  ...        0.0
# 3  36 months     14.31      514.93     C        C4  ...        0.0
# 4  36 months      6.03      456.54     A        A1  ...        0.0
#
#   collection_recovery_fee  last_payment_date last_payment_amount  \
# 0                     0.0                NaN              248.82
# ...

# %%
transformer=DateTransform(data_finance)

# %%
date_columns=[ element for element in list(data_finance.columns)  if 'date' in element]
date_columns
# Out:
# ['issue_date',
#  'last_payment_date',
#  'next_payment_date',
#  'last_credit_pull_date']

# %%
data_finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54231 entries, 0 to 54230
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           54231 non-null  int64
#  1   member_id                    54231 non-null  int64
#  2   loan_amount                  54231 non-null  int64
#  3   funded_amount                51224 non-null  float64
#  4   funded_amount_inv            54231 non-null  float64
#  5   term                         49459 non-null  object
#  6   int_rate                     49062 non-null  float64
#  7   instalment                   54231 non-null  float64
#  8   grade                        54231 non-null  object
#  9   sub_grade                    54231 non-null  object
#  10  employment_length            52113 non-null  object
#  11  home_ownership               54231 non-null  object
#  12  annual_inc                   54231 non-null  float64
# ...

# %%
transformer.convert_to_date(date_columns)
# Out:
#              id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0      38676116   41461848         8000         8000.0             8000.0
# 1      38656203   41440010        13200        13200.0            13200.0
# 2      38656154   41439961        16000        16000.0            16000.0
# 3      38656128   41439934        15000        15000.0            15000.0
# 4      38656121   41439927        15000        15000.0            15000.0
# ...         ...        ...          ...            ...                ...
# 54226     76597      76583         5000         5000.0             1775.0
# 54227    142608      74724         5000         5000.0             2350.0
# 54228    117045      70978         3500         3500.0             2225.0
# 54229     88854      70699         5000         5000.0              225.0
# 54230     72323      70694         5000         5000.0              350.0
#
#             term  int_rate  instalment grade sub_grade  ... recoveries  \
# ...

# %%
data_finance.isna().sum()/len(data_finance)*100
# Out:
# id                               0.000000
# member_id                        0.000000
# loan_amount                      0.000000
# funded_amount                    5.544799
# funded_amount_inv                0.000000
# term                             8.799395
# int_rate                         9.531449
# instalment                       0.000000
# grade                            0.000000
# sub_grade                        0.000000
# employment_length                3.905515
# home_ownership                   0.000000
# annual_inc                       0.000000
# verification_status              0.000000
# issue_date                     100.000000
# loan_status                      0.000000
# payment_plan                     0.000000
# purpose                          0.000000
# dti                              0.000000
# delinq_2yrs                      0.000000
# earliest_credit_line             0.000000
# inq_last_6mths                   0.000000
# ...

# %% [markdown]
# drop : non-essential and above 50% null
# mean or median: below 50% null , numeric
# mode: below 50% null object
# zero out: any other case

# %%
data_finance.head()
# Out:
#          id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0  38676116   41461848         8000         8000.0             8000.0
# 1  38656203   41440010        13200        13200.0            13200.0
# 2  38656154   41439961        16000        16000.0            16000.0
# 3  38656128   41439934        15000        15000.0            15000.0
# 4  38656121   41439927        15000        15000.0            15000.0
#
#         term  int_rate  instalment grade sub_grade  ... recoveries  \
# 0  36 months      7.49      248.82     A        A4  ...        0.0
# 1  36 months      6.99      407.52     A        A3  ...        0.0
# 2  36 months      7.49      497.63     A        A4  ...        0.0
# 3  36 months     14.31      514.93     C        C4  ...        0.0
# 4  36 months      6.03      456.54     A        A1  ...        0.0
#
#   collection_recovery_fee  last_payment_date last_payment_amount  \
# 0                     0.0                NaT              248.82
# ...

# %%
data_finance.describe()
# Out:
#                  id     member_id   loan_amount  funded_amount  \
# count  5.423100e+04  5.423100e+04  54231.000000   51224.000000
# mean   7.621797e+06  8.655350e+06  13333.076100   13229.509117
# min    5.552100e+04  7.069400e+04    500.000000     500.000000
# 25%    7.594330e+05  9.587720e+05   7000.000000    7000.000000
# 50%    7.084590e+06  8.709873e+06  12000.000000   12000.000000
# 75%    8.860616e+06  1.052714e+07  18000.000000   18000.000000
# max    3.867612e+07  4.146185e+07  35000.000000   35000.000000
# std    9.571362e+06  1.031281e+07   8082.196709    8019.017599
#
#        funded_amount_inv      int_rate    instalment    annual_inc issue_date  \
# count       54231.000000  49062.000000  54231.000000  5.423100e+04          0
# mean        12952.622979     13.507328    400.013953  7.222085e+04        NaT
# min             0.000000      5.420000     15.670000  3.300000e+03        NaT
# 25%          6700.000000     10.370000    224.205000  4.500000e+04        NaT
# ...

# %%
data_finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54231 entries, 0 to 54230
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           54231 non-null  int64
#  1   member_id                    54231 non-null  int64
#  2   loan_amount                  54231 non-null  int64
#  3   funded_amount                51224 non-null  float64
#  4   funded_amount_inv            54231 non-null  float64
#  5   term                         49459 non-null  object
#  6   int_rate                     49062 non-null  float64
#  7   instalment                   54231 non-null  float64
#  8   grade                        54231 non-null  object
#  9   sub_grade                    54231 non-null  object
#  10  employment_length            52113 non-null  object
#  11  home_ownership               54231 non-null  object
#  12  annual_inc                   54231 non-null  float64
# ...

# %%
data_finance=data_finance.to_csv('./loan_payments_data.csv',index=False)

# %%
data_finance=pd.read_csv('./loan_payments_data.csv')

# %%
data_finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54231 entries, 0 to 54230
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           54231 non-null  int64
#  1   member_id                    54231 non-null  int64
#  2   loan_amount                  54231 non-null  int64
#  3   funded_amount                51224 non-null  float64
#  4   funded_amount_inv            54231 non-null  float64
#  5   term                         49459 non-null  object
#  6   int_rate                     49062 non-null  float64
#  7   instalment                   54231 non-null  float64
#  8   grade                        54231 non-null  object
#  9   sub_grade                    54231 non-null  object
#  10  employment_length            52113 non-null  object
#  11  home_ownership               54231 non-null  object
#  12  annual_inc                   54231 non-null  float64
# ...

# %%
# issue is I cannot persist the date format change to loan_payment_data.csv

# %%
data_finance.describe()
# Out:
#                  id     member_id   loan_amount  funded_amount  \
# count  5.423100e+04  5.423100e+04  54231.000000   51224.000000
# mean   7.621797e+06  8.655350e+06  13333.076100   13229.509117
# std    9.571362e+06  1.031281e+07   8082.196709    8019.017599
# min    5.552100e+04  7.069400e+04    500.000000     500.000000
# 25%    7.594330e+05  9.587720e+05   7000.000000    7000.000000
# 50%    7.084590e+06  8.709873e+06  12000.000000   12000.000000
# 75%    8.860616e+06  1.052714e+07  18000.000000   18000.000000
# max    3.867612e+07  4.146185e+07  35000.000000   35000.000000
#
#        funded_amount_inv      int_rate    instalment    annual_inc  \
# count       54231.000000  49062.000000  54231.000000  5.423100e+04
# mean        12952.622979     13.507328    400.013953  7.222085e+04
# std          8099.473527      4.392893    238.920012  5.158934e+04
# min             0.000000      5.420000     15.670000  3.300000e+03
# ...

# %%
[{columns:list(data_finance[columns].unique())} for columns in data_finance.columns]
# Out:
# [{'id': [38676116,
#    38656203,
#    38656154,
#    38656128,
#    38656121,
#    38656111,
#    38656110,
#    38656067,
#    38656063,
#    38656052,
#    38656023,
#    38656004,
#    38656003,
#    38655994,
#    38655931,
#    38655925,
#    38655917,
#    38655869,
#    38655866,
#    38655854,
#    38655850,
#    38655834,
#    38655809,
#    38655801,
#    38655738,
#    38655682,
#    38655669,
#    38655644,
#    38655614,
#    38655565,
#    38655556,
#    38655526,
#    38655517,
#    38655511,
#    38655449,
#    38655432,
#    38655417,
#    38655413,
#    38655401,
#    38655386,
#    38655301,
#    38655201,
#    38655130,
#    38655125,
#    38655110,
#    38655085,
#    38655068,
#    38655066,
#    38655061,
#    38655025,
#    38655010,
#    38654951,
#    38654920,
#    38654901,
#    38654889,
#    38654876,
#    38654836,
#    38654802,
#    38654722,
#    38654719,
#    38654702,
#    38654699,
#    38654661,
#    38654653,
#    38654574,
#    38654532,
# ...

# %%
data_finance['dti'].unique()
# Out:
# array([19.54, 24.2 , 16.92, ...,  0.12,  0.47,  0.09])

# %%
data_finance.shape
# Out:
# (54231, 43)

# %%
null_percentage=data_finance.isna().sum()/len(data_finance)*100

# %%
null_percentage.index
# Out:
# Index(['id', 'member_id', 'loan_amount', 'funded_amount', 'funded_amount_inv',
#        'term', 'int_rate', 'instalment', 'grade', 'sub_grade',
#        'employment_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_date', 'loan_status', 'payment_plan',
#        'purpose', 'dti', 'delinq_2yrs', 'earliest_credit_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv',
#        'total_payment', 'total_payment_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_payment_date', 'last_payment_amount',
#        'next_payment_date', 'last_credit_pull_date',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type'],
#       dtype='object')

# %%
null_percentage.values
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.54479910e+00,
#        0.00000000e+00, 8.79939518e+00, 9.53144880e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.90551530e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5.71665652e+01, 8.86024598e+01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+02,
#        0.00000000e+00, 1.00000000e+02, 1.00000000e+02, 9.40421530e-02,
#        8.61721156e+01, 0.00000000e+00, 0.00000000e+00])

# %%
result_df=pd.DataFrame({'column_name':null_percentage.index,'missing_percentage':null_percentage.values})

# %%
result_df[result_df.missing_percentage > 50].column_name.to_list()
# Out:
# ['issue_date',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'last_payment_date',
#  'next_payment_date',
#  'last_credit_pull_date',
#  'mths_since_last_major_derog']

# %%
string_columns = [col for col in data_finance if data_finance[col].dtype == 'object' 
                  and all(isinstance(val, str) or val is None for val in data_finance[col])]

# %%
string_columns
# Out:
# ['grade',
#  'sub_grade',
#  'home_ownership',
#  'verification_status',
#  'loan_status',
#  'payment_plan',
#  'purpose',
#  'earliest_credit_line',
#  'application_type']

# %%
#  Identify Mixed Columns
mixed_columns = [col for col in data_finance.columns if data_finance[col].apply(type).nunique() > 1]
mixed_columns
# Out:
# ['term', 'employment_length']

# %%
# Identify Object Columns
object_columns = data_finance.select_dtypes(include='object').columns
object_columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'employment_length', 'home_ownership',
#        'verification_status', 'loan_status', 'payment_plan', 'purpose',
#        'earliest_credit_line', 'application_type'],
#       dtype='object')

# %%
set(object_columns).intersection(set(mixed_columns))
# Out:
# {'employment_length', 'term'}

# %%
# Identify Datetime Columns
datetime_columns = data_finance.select_dtypes(include='datetime64').columns
datetime_columns
# Out:
# Index([], dtype='object')

# %%
import pandas as pd
from scipy.stats import skew, kurtosis

def determine_distribution_category(data):
    skewness = skew(data)
    kurt = kurtosis(data)

    # Set threshold values for skewness and kurtosis
    skew_threshold = 0.5
    kurt_threshold = 2.0

    # Determine distribution category
    if abs(skewness) > skew_threshold or abs(kurt) > kurt_threshold:
        return "Skewed"
    else:
        return "Normal"

# %%
data_finance.select_dtypes(include='number').columns
# Out:
# Index(['id', 'member_id', 'loan_amount', 'funded_amount', 'funded_amount_inv',
#        'int_rate', 'instalment', 'annual_inc', 'issue_date', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_accounts', 'total_accounts',
#        'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_payment_date', 'last_payment_amount',
#        'next_payment_date', 'last_credit_pull_date',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code'],
#       dtype='object')

# %%
from data_distribution import DataDistribution
# Out:
# {'skewed_distribution': ['loan_amount', 'funded_amount', 'funded_amount_inv', 'instalment', 'annual_inc', 'delinq_2yrs', 'inq_last_6mths', 'mths_since_last_record', 'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_payment_amount', 'collections_12_mths_ex_med'], 'normal_distribution': ['int_rate', 'issue_date', 'dti', 'mths_since_last_delinq', 'last_payment_date', 'next_payment_date', 'last_credit_pull_date', 'mths_since_last_major_derog'], 'constant': ['policy_code']}
# /home/benmlengineer/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1171: RuntimeWarning: Mean of empty slice.
#   mean = a.mean(axis, keepdims=True)
# /home/benmlengineer/.local/lib/python3.10/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# ...

# %%
normality_dict=DataDistribution(data_finance).determine_distribution

# %%
print(normality_dict)
# Out:
# <bound method DataDistribution.determine_distribution of <data_distribution.DataDistribution object at 0x7f9bc026ad40>>

# %%
len(data_finance.select_dtypes(include='number').columns.to_list()
)
# Out:
# 32

# %%
numeric_columns=data_finance.select_dtypes(include='number')

# %%
numeric_columns.columns.to_list()[2:]
# Out:
# ['loan_amount',
#  'funded_amount',
#  'funded_amount_inv',
#  'int_rate',
#  'instalment',
#  'annual_inc',
#  'issue_date',
#  'dti',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_accounts',
#  'total_accounts',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_payment',
#  'total_payment_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_payment_date',
#  'last_payment_amount',
#  'next_payment_date',
#  'last_credit_pull_date',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code']

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.hist(data_finance['loan_amount'], bins=5, edgecolor='black')
# Out:
# (array([14320., 18422., 12728.,  5626.,  3135.]),
#  array([  500.,  7400., 14300., 21200., 28100., 35000.]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(data_finance['loan_amount'])
# Out:
# <Axes: ylabel='loan_amount'>

# %%
# Create a missing data matrix (1 for missing, 0 for not missing)
missing_matrix = data_finance.iloc[:,2:].isnull().astype(int)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(missing_matrix, cmap='viridis', cbar=False, yticklabels=False)
plt.title('Missing Data Matrix')
plt.show()

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import statsmodels.api as sm
# import numpy as np

# class DataVisualizer:
#     def __init__(self, df):
#         self.df = df

#     def plot_distribution(self):
#         for column in self.df.select_dtypes(include='number').columns[2:]:
#             data = self.df[column].dropna()

#             # Plot Histogram
#             plt.figure(figsize=(10, 5))
#             plt.subplot(2, 2, 1)
#             sns.histplot(data, kde=True, color='blue')
#             plt.title(f'Histogram of {column}')

#             # Plot Box Plot
#             plt.subplot(2, 2, 2)
#             sns.boxplot(x=data, color='orange')
#             plt.title(f'Box Plot of {column}')

#             # Plot Kernel Density Plot
#             plt.subplot(2, 2, 3)
#             sns.kdeplot(data, fill=True, color='green')
#             plt.title(f'Kernel Density Plot of {column}')

#             # Plot QQ Plot
#             plt.subplot(2, 2, 4)
#             sm.qqplot(np.array(data), line='45', fit=True)
#             plt.title(f'QQ Plot of {column}')

#             plt.tight_layout()
#             plt.show()

#             # Wait for user input (press Enter) to proceed to the next plot
#             input("Press Enter to continue...")


# df = pd.DataFrame(data_finance)
# visualizer = DataVisualizer(df)
# visualizer.plot_distribution()

# %%
data_finance.isna().sum()
# Out:
# id                                 0
# member_id                          0
# loan_amount                        0
# funded_amount                   3007
# funded_amount_inv                  0
# term                            4772
# int_rate                        5169
# instalment                         0
# grade                              0
# sub_grade                          0
# employment_length               2118
# home_ownership                     0
# annual_inc                         0
# verification_status                0
# issue_date                     54231
# loan_status                        0
# payment_plan                       0
# purpose                            0
# dti                                0
# delinq_2yrs                        0
# earliest_credit_line               0
# inq_last_6mths                     0
# mths_since_last_delinq         31002
# mths_since_last_record         48050
# open_accounts                      0
# ...

# %%
data_finance.policy_code.value_counts()
# Out:
# policy_code
# 1    54231
# Name: count, dtype: int64

# %%
data_finance.columns.to_list().index('application_type')
# Out:
# 42

# %%
data_finance.application_type.value_counts()
# Out:
# application_type
# INDIVIDUAL    54231
# Name: count, dtype: int64

# %%
len(data_finance)
# Out:
# 54231

# %%
data_finance.columns.to_list().index('mths_since_last_major_derog')
# Out:
# 40

# %%
[0,1,2,3][1:3]
# Out:
# [1, 2]

# %%
data_finance['annual_inc'].mean()
# Out:
# 72220.84824897199

# %%
category_columns_to_impute= data_finance.select_dtypes(include='object').columns.to_list()

# %%
category_columns_to_impute
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'employment_length',
#  'home_ownership',
#  'verification_status',
#  'loan_status',
#  'payment_plan',
#  'purpose',
#  'earliest_credit_line',
#  'application_type']

# %%
data_type=[]
for a in category_columns_to_impute:
    data_type.append(type(data_finance[a].dtype))
data_type
# Out:
# [numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType,
#  numpy.dtypes.ObjectDType]

# %%
processed_df=data_finance.copy()

# %%
for col in category_columns_to_impute:
    mode_value=processed_df[col].mode()[0]
    processed_df[col].fillna(mode_value,inplace=True)

# %%
processed_df.head()
# Out:
#          id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 0  38676116   41461848         8000         8000.0             8000.0
# 1  38656203   41440010        13200        13200.0            13200.0
# 2  38656154   41439961        16000        16000.0            16000.0
# 3  38656128   41439934        15000        15000.0            15000.0
# 4  38656121   41439927        15000        15000.0            15000.0
#
#         term  int_rate  instalment grade sub_grade  ... recoveries  \
# 0  36 months      7.49      248.82     A        A4  ...        0.0
# 1  36 months      6.99      407.52     A        A3  ...        0.0
# 2  36 months      7.49      497.63     A        A4  ...        0.0
# 3  36 months     14.31      514.93     C        C4  ...        0.0
# 4  36 months      6.03      456.54     A        A1  ...        0.0
#
#   collection_recovery_fee  last_payment_date last_payment_amount  \
# 0                     0.0                NaN              248.82
# ...

# %%
dd=DataDistribution(new_df)
print(dd.determine_distribution())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 dd=DataDistribution(new_df)
#       2 print(dd.determine_distribution())
#
# NameError: name 'new_df' is not defined

# %%
from collections import defaultdict
new_dict=defaultdict(list)
for key,value in dd.determine_distribution().items():
    new_dict[value].append(key)
print(dict(new_dict))
# Out:
# {'skewed': ['funded_amount', 'funded_amount_inv', 'instalment', 'annual_inc', 'delinq_2yrs', 'inq_last_6mths', 'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_payment_amount', 'collections_12_mths_ex_med'], 'normal': ['int_rate', 'dti'], 'constant': ['policy_code']}
# /home/benmlengineer/Documents/Aicore/exploratory-data-analysis---customer-loans-in-finance833/data_distribution.py:20: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = skew(column_values,nan_policy='omit')
# ...

# %%
{'normal': ['loan_amount', 'funded_amount', 'funded_amount_inv',
   'int_rate', 'instalment', 'issue_date', 
   'dti', 'mths_since_last_delinq', 'mths_since_last_record',
     'open_accounts', 'total_accounts', 
     'total_payment', 'total_payment_inv', 'total_rec_prncp',
       'last_payment_date', 'next_payment_date', 'last_credit_pull_date', 
       'mths_since_last_major_derog'], 
'skewed': ['annual_inc', 'delinq_2yrs', 'inq_last_6mths', 
           'out_prncp', 'out_prncp_inv', 'total_rec_int', 
           'total_rec_late_fee', 'recoveries', 
           'collection_recovery_fee', 'last_payment_amount', 
           'collections_12_mths_ex_med'], 
'constant': ['policy_code']}

# %%
processed_df[dict(new_dict)['normal']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 processed_df[[dict(new_dict)['normal']]]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
# ...

# %%
dict(new_dict)['skewed']
# Out:
# ['funded_amount',
#  'funded_amount_inv',
#  'instalment',
#  'annual_inc',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'open_accounts',
#  'total_accounts',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_payment',
#  'total_payment_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_payment_amount',
#  'collections_12_mths_ex_med']

# %%
sum([len(x) for x in dict(new_dict).values()])
# Out:
# 22

# %%
set(data_finance.columns.to_list()).difference(set(dd.determine_distribution().keys()))
# Out:
# /home/benmlengineer/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1171: RuntimeWarning: Mean of empty slice.
#   mean = a.mean(axis, keepdims=True)
# /home/benmlengineer/.local/lib/python3.10/site-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /home/benmlengineer/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/benmlengineer/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/benmlengineer/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1281: RuntimeWarning: Mean of empty slice.
#   mean = a.mean(axis, keepdims=True)
# ...

# %%
new_df=data_finance.copy()

# %%
null_ratio=new_df.isna().sum()/len(new_df)

# %%
null_percentage_df=pd.DataFrame({'column_name': null_ratio.index, 'percentage_values':null_ratio.values*100})

# %%
null_percentage_df
# Out:
#                     column_name  percentage_values
# 0                            id           0.000000
# 1                     member_id           0.000000
# 2                   loan_amount           0.000000
# 3                 funded_amount           5.544799
# 4             funded_amount_inv           0.000000
# 5                          term           8.799395
# 6                      int_rate           9.531449
# 7                    instalment           0.000000
# 8                         grade           0.000000
# 9                     sub_grade           0.000000
# 10            employment_length           3.905515
# 11               home_ownership           0.000000
# 12                   annual_inc           0.000000
# 13          verification_status           0.000000
# 14                   issue_date         100.000000
# 15                  loan_status           0.000000
# 16                 payment_plan           0.000000
# ...

# %%
columns_to_drop=null_percentage_df[null_percentage_df.percentage_values > 50]

# %%
columns_to_drop=columns_to_drop.column_name.to_list()

# %%
new_df=new_df.drop(columns=columns_to_drop)

# %%
len(data_finance.columns) - len(new_df.columns)
# Out:
# 7

# %%
category_columns_to_impute=new_df.select_dtypes(include='object').columns.to_list()
len(category_columns_to_impute)
# Out:
# 11

# %%
numeric_columns_to_impute=new_df.select_dtypes(include='number').columns.to_list()
len(numeric_columns_to_impute)
# Out:
# 25

# %%
len(data_finance.columns)
# Out:
# 43

# %%
data_finance.columns.to_list().index('policy_code')
# Out:
# 41

# %%
len(data_finance.select_dtypes(include='number').columns.to_list())
# Out:
# 32

# %%
data_finance.columns.to_list().index('application_type')
# Out:
# 42

# %%
my_dict={'skewed': ['loan_amount', 'funded_amount', 'funded_amount_inv', 'instalment', 'annual_inc', 'delinq_2yrs', 'inq_last_6mths', 'mths_since_last_record', 'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_payment_amount', 'collections_12_mths_ex_med'], 'normal': ['int_rate', 'issue_date', 'dti', 'mths_since_last_delinq', 'last_payment_date', 'next_payment_date', 'last_credit_pull_date', 'mths_since_last_major_derog'], 'constant': ['policy_code']}

# %%
list(my_dict.values())
# Out:
# [['loan_amount',
#   'funded_amount',
#   'funded_amount_inv',
#   'instalment',
#   'annual_inc',
#   'delinq_2yrs',
#   'inq_last_6mths',
#   'mths_since_last_record',
#   'open_accounts',
#   'total_accounts',
#   'out_prncp',
#   'out_prncp_inv',
#   'total_payment',
#   'total_payment_inv',
#   'total_rec_prncp',
#   'total_rec_int',
#   'total_rec_late_fee',
#   'recoveries',
#   'collection_recovery_fee',
#   'last_payment_amount',
#   'collections_12_mths_ex_med'],
#  ['int_rate',
#   'issue_date',
#   'dti',
#   'mths_since_last_delinq',
#   'last_payment_date',
#   'next_payment_date',
#   'last_credit_pull_date',
#   'mths_since_last_major_derog'],
#  ['policy_code']]

# %%
import itertools
merged = list(itertools.chain.from_iterable(list(my_dict.values())))

# %%
len(merged)
# Out:
# 30

# %%
merged
# Out:
# ['loan_amount',
#  'funded_amount',
#  'funded_amount_inv',
#  'instalment',
#  'annual_inc',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'mths_since_last_record',
#  'open_accounts',
#  'total_accounts',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_payment',
#  'total_payment_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_payment_amount',
#  'collections_12_mths_ex_med',
#  'int_rate',
#  'issue_date',
#  'dti',
#  'mths_since_last_delinq',
#  'last_payment_date',
#  'next_payment_date',
#  'last_credit_pull_date',
#  'mths_since_last_major_derog',
#  'policy_code']
